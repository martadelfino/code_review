# %% [markdown]
# Example script.
#
# Calculating LD scores for 6 random rs IDs in the toy data. (rs1050979, rs45626136, rs3093664, rs1015166, rs72928038, rs9354144)

# %%
# Requirements

import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import itertools
import os
os.getcwd()

import src.PyLD as PyLD
import src.heatmaps as heatmaps

# %%
# LD scores
rs_id_list = ['rs1050979', 'rs45626136', 'rs3093664', 'rs1015166', 'rs72928038', 'rs9354144']
rs_id_LD_measures = PyLD.LD('data/toy_data.vcf', rs_id_list)
dictionary_of_ld_measures = rs_id_LD_measures.calculate_LD_measures()
print(dictionary_of_ld_measures)
# Out:
# [{'rsID_1': 'rs1050979', 'rsID_2': 'rs45626136', 'haplotypes': {'00': 96, '01': 5, '10': 92, '11': 7}, 'pA': 0.505, 'pB': 0.94, 'pAB': 0.48, 'D': 0.005300000000000027, 'r^2': 0.0019923978213424367, 'Dprime': 0.17491749174917565}, {'rsID_1': 'rs1050979', 'rsID_2': 'rs3093664', 'haplotypes': {'00': 87, '01': 14, '10': 87, '11': 12}, 'pA': 0.505, 'pB': 0.87, 'pAB': 0.435, 'D': -0.0043500000000000205, 'r^2': 0.0006692976990006756, 'Dprime': 0.06759906759906792}, {'rsID_1': 'rs1050979', 'rsID_2': 'rs1015166', 'haplotypes': {'00': 71, '01': 30, '10': 66, '11': 33}, 'pA': 0.505, 'pB': 0.685, 'pAB': 0.355, 'D': 0.009074999999999944, 'r^2': 0.001526847158125596, 'Dprime': 0.05704856199905671}, {'rsID_1': 'rs1050979', 'rsID_2': 'rs72928038', 'haplotypes': {'00': 77, '01': 24, '10': 79, '11': 20}, 'pA': 0.505, 'pB': 0.78, 'pAB': 0.385, 'D': -0.008900000000000019, 'r^2': 0.0018465716035473091, 'Dprime': 0.08172635445362737}, {'rsID_1': 'rs1050979', 'rsID_2': 'rs9354144', 'haplotypes': {'00': 91,
# ...

# %%
# Save results
rs_id_LD_measures.save_results('data/toy_data_output.csv')

# %%
# Create heatmap of results

heatmaps.LD_heatmaps(dictionary_of_ld_measures, rs_id_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Create heatmap of results
# ----> 3 heatmaps.LD_heatmaps(dictionary_of_ld_measures, rs_id_list)
#
# File ~/PyLD/heatmaps.py:104, in LD_heatmaps(results_pairwise_LD, rsID_list)
#     102 ### DPRIME HEATMAP
#     103 dprime_heatmap = heatmap(dprime_values, rsID_list, dprime_title)
# --> 104 plt.savefig("static/dprime.png")
#
# File ~/PyLD/PyLD_env/lib/python3.9/site-packages/matplotlib/pyplot.py:1134, in savefig(*args, **kwargs)
#    1131 fig = gcf()
#    1132 # savefig default implementation has no return, so mypy is unhappy
#    1133 # presumably this is here because subclasses can return?
# -> 1134 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1135 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1136 return res
#
# ...
